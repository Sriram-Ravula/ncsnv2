# %%
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt

import torchvision
from torchvision import transforms

# %% [markdown]
# ## Grab the test data and visualise

# %%
data_path = "/home/sravula/experiments/datasets/8047_vel_imgs.npy"

# %%
from datasets.velocity_fine import Velocity

tran_transform = transforms.Compose([
    transforms.Resize([256, 256])
])

dataset = Velocity(path=data_path, transform=tran_transform)

# %%
N = len(dataset)
indices = list(range(N))
np.random.seed(2240)
np.random.shuffle(indices)
train_indices, test_indices = indices[:int(N * 0.9)], indices[int(N * 0.9):]

# %%
test_dataset = torch.utils.data.Subset(dataset, test_indices)

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=25, shuffle=False,
                         num_workers=8, drop_last=True)

test_iter = iter(test_loader)

test_sample = next(test_iter)[0]

# %%
grid_img = torchvision.utils.make_grid(test_sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()

# %% [markdown]
# ## Noise the test data and visualise

# %%
noisy_test_sample = test_sample + 0.15*torch.randn(test_sample.size())
noisy_test_sample = torch.clip(noisy_test_sample, min=0, max=1)

# %%
grid_img = torchvision.utils.make_grid(noisy_test_sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()

# %% [markdown]
# ## Load the network and perform Langevin dynamics on the noisy images

# %%
ckpt_path = "/home/sravula/experiments/logs/run_2/checkpoint.pth"
config_path = "/home/sravula/ncsnv2/configs/velocity.yml"

# %%
import argparse
from main import dict2namespace
import yaml

with open(config_path, 'r') as f:
    config = yaml.load(f)
new_config = dict2namespace(config)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
new_config.device = device

print(device)
# Out:
# /home/sravula/venvs/ncsnv2/lib64/python3.6/site-packages/ipykernel_launcher.py:6: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# cuda

# %%
from models.ncsnv2 import NCSNv2Deepest
from models.ema import EMAHelper
from models import get_sigmas

new_config.input_dim = new_config.data.image_size ** 2 * new_config.data.channels

score = NCSNv2Deepest(new_config).to(new_config.device)
score = torch.nn.DataParallel(score)

#Set up the exponential moving average
if new_config.model.ema:
    ema_helper = EMAHelper(mu=new_config.model.ema_rate)
    ema_helper.register(score)

states = torch.load(ckpt_path)
score.load_state_dict(states[0])
### Make sure we can resume with different eps
states[1]['param_groups'][0]['eps'] = new_config.optim.eps

if new_config.model.ema:
    ema_helper.load_state_dict(states[4])

#grab all L noise levels
sigmas = get_sigmas(new_config)

# %%
test_score = ema_helper.ema_copy(score)

test_score.eval()
# Out:
# DataParallel(
#   (module): NCSNv2Deepest(
#     (act): ELU(alpha=1.0)
#     (begin_conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (normalizer): InstanceNorm2dPlus(
#       (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#     (end_conv): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (res1): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res2): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res3): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res31): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res4): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (shortcut): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res5): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (shortcut): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (refine1): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine2): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine3): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine31): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine4): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine5): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#   )
# )

# %%
from models import langevin_Inverse
import time

N, C, H, W = noisy_test_sample.shape
print(N, C, H, W)

y = noisy_test_sample.to(new_config.device)

#A = torch.eye(C*H*W, device=new_config.device, dtype=torch.bool)

x0 = torch.rand(N, C, H, W, device=new_config.device)

start = time.time()

all_samples = langevin_Inverse(x_mod = x0, 
                                       y = y, 
                                       A = None, 
                                       scorenet = test_score, 
                                       sigmas = sigmas.cpu().numpy(), 
                                       n_steps_each=new_config.sampling.n_steps_each,
                                       step_lr=new_config.sampling.step_lr,
                                       final_only=True, 
                                       verbose=True,
                                       denoise=True,
                                       add_noise=False, 
                                       decimate_sigma=25,
                                       mode='denoising')

print("\nTOTAL TIME: ", time.time() - start)
# Out:
# 25 1 256 256
# /home/sravula/venvs/ncsnv2/lib64/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# level: 0, step_size: 90.0000, prior_norm: 3.4050, likelihood_norm: 4.6631, grad_norm: 7.4769                             image_norm: 643.9370, snr: inf, prior_mean_norm: 3578.7649, likelihood_mean_norm: 11.2331, grad_mean_norm: 15.3255, mse: 0.2074
# level: 0, step_size: 90.0000, prior_norm: 3.2111, likelihood_norm: 22.5493, grad_norm: 25.5980                             image_norm: 1696.1089, snr: inf, prior_mean_norm: 3443.2178, likelihood_mean_norm: 116.5309, grad_mean_norm: 131.2950, mse: 4.8492
# level: 0, step_size: 90.0000, prior_norm: 3.2059, likelihood_norm: 69.6299, grad_norm: 72.7260                             image_norm: 4858.8843, snr: inf, prior_mean_norm: 3698.6006, likelihood_mean_norm: 928.1442, grad_mean_norm: 972.6260, mse: 46.2374
# level: 1, step_size: 59.9712, prior_norm: 3.0210, likelihood_norm: 192.1900, grad_norm: 195.1314                             image_norm: 6849.0947, snr: inf, prior_mean_norm: 2484.1821, likelihood_mean_norm: 6692.9731, grad_mean_norm: 6816.8081, mse: 352.2599
# level: 1, step_size: 59.9712, prior_norm: 3.1027, likelihood_norm: 275.9029, grad_norm: 278.9250                             image_norm: 9881.4551, snr: inf, prior_mean_norm: 2557.2029, likelihood_mean_norm: 13513.8193, grad_mean_norm: 13691.3330, mse: 725.9622
# level: 1, step_size: 59.9712, prior_norm: 3.0155, likelihood_norm: 393.1978, grad_norm: 396.1398                             image_norm: 13878.3525, snr: inf, prior_mean_norm: 2478.8989, likelihood_mean_norm: 27040.8965, grad_mean_norm: 27289.7832, mse: 1474.4281
# level: 2, step_size: 39.9617, prior_norm: 3.1103, likelihood_norm: 557.0829, grad_norm: 560.1178                             image_norm: 8507.2607, snr: inf, prior_mean_norm: 1731.4783, likelihood_mean_norm: 53749.8672, grad_mean_norm: 54107.7891, mse: 2959.6550
# level: 2, step_size: 39.9617, prior_norm: 3.0589, likelihood_norm: 338.2480, grad_norm: 341.2350                             image_norm: 5134.1348, snr: inf, prior_mean_norm: 1683.0415, likelihood_mean_norm: 19594.6973, grad_mean_norm: 19808.8223, mse: 1091.1178
# level: 2, step_size: 39.9617, prior_norm: 3.1803, likelihood_norm: 207.2065, grad_norm: 210.3107                             image_norm: 3276.5024, snr: inf, prior_mean_norm: 1735.1420, likelihood_mean_norm: 7224.0039, grad_mean_norm: 7355.1245, mse: 409.4567
# level: 3, step_size: 26.6283, prior_norm: 3.1613, likelihood_norm: 128.9713, grad_norm: 132.0626                             image_norm: 304.3471, snr: inf, prior_mean_norm: 1144.2493, likelihood_mean_norm: 2713.9133, grad_mean_norm: 2794.6233, mse: 158.6306
# level: 3, step_size: 26.6283, prior_norm: 3.4819, likelihood_norm: 11.7130, grad_norm: 15.0990                             image_norm: 217.0780, snr: inf, prior_mean_norm: 1002.1639, likelihood_mean_norm: 17.8453, grad_mean_norm: 23.8030, mse: 1.3084
# level: 3, step_size: 26.6283, prior_norm: 3.5165, likelihood_norm: 4.4490, grad_norm: 7.8727                             image_norm: 196.4809, snr: inf, prior_mean_norm: 833.2104, likelihood_mean_norm: 1.1304, grad_mean_norm: 2.8589, mse: 0.1888
# level: 4, step_size: 17.7437, prior_norm: 3.5594, likelihood_norm: 4.0226, grad_norm: 7.4795                             image_norm: 178.2032, snr: inf, prior_mean_norm: 571.6055, likelihood_mean_norm: 0.6580, grad_mean_norm: 2.2702, mse: 0.1543
# level: 4, step_size: 17.7437, prior_norm: 3.5416, likelihood_norm: 1.4711, grad_norm: 4.6644                             image_norm: 178.3239, snr: inf, prior_mean_norm: 562.4770, likelihood_mean_norm: 0.0891, grad_mean_norm: 0.8766, mse: 0.0206
# level: 4, step_size: 17.7437, prior_norm: 3.5510, likelihood_norm: 2.2469, grad_norm: 5.5432                             image_norm: 182.6911, snr: inf, prior_mean_norm: 565.9194, likelihood_mean_norm: 0.2053, grad_mean_norm: 1.2370, mse: 0.0481
# level: 5, step_size: 11.8235, prior_norm: 3.5725, likelihood_norm: 2.0211, grad_norm: 5.3696                             image_norm: 173.8326, snr: inf, prior_mean_norm: 380.8495, likelihood_mean_norm: 0.1669, grad_mean_norm: 1.1608, mse: 0.0390
# level: 5, step_size: 11.8235, prior_norm: 3.5410, likelihood_norm: 1.0010, grad_norm: 3.3614                             image_norm: 175.3057, snr: inf, prior_mean_norm: 376.2701, likelihood_mean_norm: 0.0424, grad_mean_norm: 0.4576, mse: 0.0096
# level: 5, step_size: 11.8235, prior_norm: 3.5566, likelihood_norm: 1.9083, grad_norm: 5.1606                             image_norm: 176.9029, snr: inf, prior_mean_norm: 379.7647, likelihood_mean_norm: 0.1491, grad_mean_norm: 1.0770, mse: 0.0347
# level: 6, step_size: 7.8785, prior_norm: 3.5814, likelihood_norm: 1.1240, grad_norm: 4.2630                             image_norm: 173.4684, snr: inf, prior_mean_norm: 256.4461, likelihood_mean_norm: 0.0532, grad_mean_norm: 0.7347, mse: 0.0120
# level: 6, step_size: 7.8785, prior_norm: 3.5577, likelihood_norm: 0.9925, grad_norm: 2.7297                             image_norm: 173.7771, snr: inf, prior_mean_norm: 249.7475, likelihood_mean_norm: 0.0420, grad_mean_norm: 0.2982, mse: 0.0094
# level: 6, step_size: 7.8785, prior_norm: 3.5308, likelihood_norm: 1.7479, grad_norm: 5.1423                             image_norm: 175.3629, snr: inf, prior_mean_norm: 247.2545, likelihood_mean_norm: 0.1242, grad_mean_norm: 1.0577, mse: 0.0291
# level: 7, step_size: 5.2498, prior_norm: 3.5809, likelihood_norm: 0.5596, grad_norm: 3.5459                             image_norm: 173.4929, snr: inf, prior_mean_norm: 169.3590, likelihood_mean_norm: 0.0150, grad_mean_norm: 0.5037, mse: 0.0030
# level: 7, step_size: 5.2498, prior_norm: 3.5792, likelihood_norm: 0.9245, grad_norm: 2.6861                             image_norm: 173.2931, snr: inf, prior_mean_norm: 168.4948, likelihood_mean_norm: 0.0367, grad_mean_norm: 0.2887, mse: 0.0082
# level: 7, step_size: 5.2498, prior_norm: 3.5535, likelihood_norm: 1.4726, grad_norm: 4.9516                             image_norm: 174.4896, snr: inf, prior_mean_norm: 166.4768, likelihood_mean_norm: 0.0889, grad_mean_norm: 0.9810, mse: 0.0207
# level: 8, step_size: 3.4982, prior_norm: 3.5985, likelihood_norm: 0.5451, grad_norm: 3.2308                             image_norm: 173.4977, snr: inf, prior_mean_norm: 113.9857, likelihood_mean_norm: 0.0141, grad_mean_norm: 0.4181, mse: 0.0028
# level: 8, step_size: 3.4982, prior_norm: 3.6044, likelihood_norm: 0.9007, grad_norm: 2.7483                             image_norm: 173.2065, snr: inf, prior_mean_norm: 113.9501, likelihood_mean_norm: 0.0347, grad_mean_norm: 0.3022, mse: 0.0077

# %%
sample = all_samples[-1].view(all_samples[-1].shape[0], new_config.data.channels,
                              new_config.data.image_size,
                              new_config.data.image_size)

sample = torch.clamp(sample, 0.0, 1.0)

# %%
grid_img = torchvision.utils.make_grid(sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()

# %% [markdown]
# from models import anneal_Langevin_dynamics
#
# noisy_test_sample = noisy_test_sample.to(new_config.device)
#
# all_samples = anneal_Langevin_dynamics(x_mod=noisy_test_sample,
#                                        scorenet=test_score,
#                                        sigmas=sigmas.cpu().numpy(),
#                                        n_steps_each=new_config.sampling.n_steps_each,
#                                        step_lr=new_config.sampling.step_lr,
#                                        final_only=True,
#                                        verbose=True,
#                                        denoise=new_config.sampling.denoise,
#                                        add_noise=False)

# %% [markdown]
# sample = all_samples[-1].view(all_samples[-1].shape[0], new_config.data.channels,
#                               new_config.data.image_size,
#                               new_config.data.image_size)
#
# sample = torch.clamp(sample, 0.0, 1.0)

# %% [markdown]
# grid_img = torchvision.utils.make_grid(sample, nrow=5)
#
# dpi = matplotlib.rcParams['figure.dpi']
#
# height = width = 6*256
# figsize = width / float(dpi), height / float(dpi)
#
# plt.figure(figsize=figsize)
# plt.imshow(grid_img.permute(1, 2, 0))
# plt.show()
