# %%
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt

import torchvision
from torchvision import transforms

# %% [markdown]
# ## Grab the test data and visualise

# %%
data_path = "/home/sravula/experiments/datasets/8047_vel_imgs.npy"

# %%
from datasets.velocity_fine import Velocity

tran_transform = transforms.Compose([
    transforms.Resize([256, 256])
])

dataset = Velocity(path=data_path, transform=tran_transform)

# %%
N = len(dataset)
indices = list(range(N))
random_state = np.random.get_state()
np.random.seed(2240)
np.random.shuffle(indices)
np.random.set_state(random_state)
train_indices, test_indices = indices[:int(N * 0.9)], indices[int(N * 0.9):]

# %%
test_dataset = torch.utils.data.Subset(dataset, test_indices)

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=15, shuffle=False,
                         num_workers=8, drop_last=True)

test_iter = iter(test_loader)

test_sample = next(test_iter)[0]

# %%
grid_img = torchvision.utils.make_grid(test_sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()

# %% [markdown]
# ## Noise the test data and visualise

# %%
#We want y = Ax where A is a random Gaussian
#y = [N, m, 1], A = [N, m, C x W x H], x = [N, C, H, W]

N, C, H, W = test_sample.shape

m = 5000

# %%
A = (1 / m) * torch.randn(m, C*H*W)
y = torch.matmul(A, test_sample.view(N, -1, 1))

print(A.shape)
print(y.shape)
print(test_sample.shape)
# Out:
# torch.Size([5000, 65536])
# torch.Size([15, 5000, 1])
# torch.Size([15, 1, 256, 256])

# %% [markdown]
# ## Load the network and perform Langevin dynamics on the noisy images

# %%
ckpt_path = "/home/sravula/experiments/logs/run_2/checkpoint.pth"
config_path = "/home/sravula/ncsnv2/configs/velocity.yml"

# %%
import argparse
from main import dict2namespace
import yaml

with open(config_path, 'r') as f:
    config = yaml.load(f)
new_config = dict2namespace(config)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
new_config.device = device

print(device)
# Out:
# cuda
# /home/sravula/venvs/ncsnv2/lib64/python3.6/site-packages/ipykernel_launcher.py:6: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
from models.ncsnv2 import NCSNv2Deepest
from models.ema import EMAHelper
from models import get_sigmas

new_config.input_dim = new_config.data.image_size ** 2 * new_config.data.channels

score = NCSNv2Deepest(new_config).to(new_config.device)
score = torch.nn.DataParallel(score)

#Set up the exponential moving average
if new_config.model.ema:
    ema_helper = EMAHelper(mu=new_config.model.ema_rate)
    ema_helper.register(score)

states = torch.load(ckpt_path)
score.load_state_dict(states[0])
### Make sure we can resume with different eps
states[1]['param_groups'][0]['eps'] = new_config.optim.eps

if new_config.model.ema:
    ema_helper.load_state_dict(states[4])

#grab all L noise levels
sigmas = get_sigmas(new_config)

# %%
test_score = ema_helper.ema_copy(score)

test_score.eval()
# Out:
# DataParallel(
#   (module): NCSNv2Deepest(
#     (act): ELU(alpha=1.0)
#     (begin_conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (normalizer): InstanceNorm2dPlus(
#       (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#     (end_conv): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (res1): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res2): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res3): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res31): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res4): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (shortcut): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res5): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (shortcut): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (refine1): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine2): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine3): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine31): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine4): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine5): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#   )
# )

# %%
from models import langevin_Inverse
import time

N, C, H, W = test_sample.shape
print(N, C, H, W)

y = y.to(new_config.device)

A = A.to(new_config.device)

x0 = torch.rand(N, C, H, W, device=new_config.device)

start = time.time()

all_samples = langevin_Inverse(x_mod = x0, 
                                       y = y, 
                                       A = A, 
                                       scorenet = test_score, 
                                       sigmas = sigmas.cpu().numpy(), 
                                       n_steps_each=1,
                                       step_lr=new_config.sampling.step_lr,
                                       final_only=True, 
                                       verbose=True,
                                       denoise=False,
                                       add_noise=False, 
                                       decimate_sigma=1100//100,
                                       mode=None,
                                       true_x=test_sample.to(new_config.device))

print("\nTOTAL TIME: ", time.time() - start)
# Out:
# 15 1 256 256
# /home/sravula/venvs/ncsnv2/lib64/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# level: 0, step_size: 5.0000, prior_norm: 3.4065, likelihood_norm: 0.0883, grad_norm: 3.4242                             image_norm: 140.4353, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0047, grad_mean_norm: 0.9646, train_mse: 0.0006
#  true_mse: 0.1726
#
# level: 1, step_size: 4.8384, prior_norm: 3.4495, likelihood_norm: 0.0784, grad_norm: 3.4627                             image_norm: 134.8633, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0042, grad_mean_norm: 0.9496, train_mse: 0.0004
#  true_mse: 0.1431
#
# level: 2, step_size: 4.6821, prior_norm: 3.4883, likelihood_norm: 0.0705, grad_norm: 3.4972                             image_norm: 131.2759, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0039, grad_mean_norm: 0.9428, train_mse: 0.0004
#  true_mse: 0.1229
#
# level: 3, step_size: 4.5308, prior_norm: 3.5655, likelihood_norm: 0.0651, grad_norm: 3.5703                             image_norm: 129.6121, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0037, grad_mean_norm: 0.9742, train_mse: 0.0003
#  true_mse: 0.1111
#
# level: 4, step_size: 4.3844, prior_norm: 3.6718, likelihood_norm: 0.0624, grad_norm: 3.6712                             image_norm: 129.7926, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0036, grad_mean_norm: 1.0095, train_mse: 0.0003
#  true_mse: 0.1081
#
# level: 5, step_size: 4.2427, prior_norm: 3.6077, likelihood_norm: 0.0635, grad_norm: 3.6122                             image_norm: 130.0346, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0037, grad_mean_norm: 0.9845, train_mse: 0.0003
#  true_mse: 0.1053
#
# level: 6, step_size: 4.1056, prior_norm: 3.5976, likelihood_norm: 0.0608, grad_norm: 3.5970                             image_norm: 130.2441, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0034, grad_mean_norm: 0.9716, train_mse: 0.0003
#  true_mse: 0.1028
#
# level: 7, step_size: 3.9730, prior_norm: 3.6272, likelihood_norm: 0.0620, grad_norm: 3.6315                             image_norm: 130.4886, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0036, grad_mean_norm: 0.9962, train_mse: 0.0003
#  true_mse: 0.1005
#
# level: 8, step_size: 3.8446, prior_norm: 3.6529, likelihood_norm: 0.0595, grad_norm: 3.6523                             image_norm: 130.6830, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0033, grad_mean_norm: 1.0012, train_mse: 0.0003
#  true_mse: 0.0983
#
# level: 9, step_size: 3.7204, prior_norm: 3.6914, likelihood_norm: 0.0606, grad_norm: 3.6955                             image_norm: 130.9147, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0034, grad_mean_norm: 1.0274, train_mse: 0.0003
#  true_mse: 0.0963
#
# level: 10, step_size: 3.6002, prior_norm: 3.7249, likelihood_norm: 0.0583, grad_norm: 3.7244                             image_norm: 131.0912, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0031, grad_mean_norm: 1.0378, train_mse: 0.0002
#  true_mse: 0.0943
#
# level: 11, step_size: 3.4838, prior_norm: 3.7625, likelihood_norm: 0.0593, grad_norm: 3.7664                             image_norm: 131.3027, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0032, grad_mean_norm: 1.0616, train_mse: 0.0002
#  true_mse: 0.0926
#
# level: 12, step_size: 3.3713, prior_norm: 3.7985, likelihood_norm: 0.0573, grad_norm: 3.7981                             image_norm: 131.4657, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0030, grad_mean_norm: 1.0757, train_mse: 0.0002
#  true_mse: 0.0909
#
# level: 13, step_size: 3.2623, prior_norm: 3.8326, likelihood_norm: 0.0582, grad_norm: 3.8362                             image_norm: 131.6574, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0031, grad_mean_norm: 1.0957, train_mse: 0.0002
#  true_mse: 0.0894
#
# level: 14, step_size: 3.1569, prior_norm: 3.8691, likelihood_norm: 0.0564, grad_norm: 3.8688                             image_norm: 131.8034, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0029, grad_mean_norm: 1.1121, train_mse: 0.0002
#  true_mse: 0.0879
#
# level: 15, step_size: 3.0549, prior_norm: 3.9013, likelihood_norm: 0.0572, grad_norm: 3.9047                             image_norm: 131.9789, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0030, grad_mean_norm: 1.1292, train_mse: 0.0002
#  true_mse: 0.0867
#
# level: 16, step_size: 2.9562, prior_norm: 3.9372, likelihood_norm: 0.0556, grad_norm: 3.9369                             image_norm: 132.1124, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0028, grad_mean_norm: 1.1452, train_mse: 0.0002
#  true_mse: 0.0853
#
# level: 17, step_size: 2.8607, prior_norm: 3.9712, likelihood_norm: 0.0563, grad_norm: 3.9744                             image_norm: 132.2731, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0029, grad_mean_norm: 1.1633, train_mse: 0.0002
#  true_mse: 0.0842
#
# level: 18, step_size: 2.7683, prior_norm: 4.0060, likelihood_norm: 0.0549, grad_norm: 4.0059                             image_norm: 132.3936, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0027, grad_mean_norm: 1.1795, train_mse: 0.0002
#  true_mse: 0.0830
#
# level: 19, step_size: 2.6788, prior_norm: 4.0421, likelihood_norm: 0.0555, grad_norm: 4.0451                             image_norm: 132.5406, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0028, grad_mean_norm: 1.1982, train_mse: 0.0002
#  true_mse: 0.0821
#
# level: 20, step_size: 2.5922, prior_norm: 4.0761, likelihood_norm: 0.0542, grad_norm: 4.0761                             image_norm: 132.6478, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0027, grad_mean_norm: 1.2126, train_mse: 0.0002
#  true_mse: 0.0810
#
# level: 21, step_size: 2.5085, prior_norm: 4.1139, likelihood_norm: 0.0548, grad_norm: 4.1166                             image_norm: 132.7814, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0027, grad_mean_norm: 1.2321, train_mse: 0.0002
#  true_mse: 0.0802
#
# level: 22, step_size: 2.4274, prior_norm: 4.1468, likelihood_norm: 0.0537, grad_norm: 4.1469                             image_norm: 132.8784, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0026, grad_mean_norm: 1.2475, train_mse: 0.0002
#  true_mse: 0.0792
#
# level: 23, step_size: 2.3490, prior_norm: 4.1863, likelihood_norm: 0.0541, grad_norm: 4.1888                             image_norm: 133.0007, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0027, grad_mean_norm: 1.2662, train_mse: 0.0002
#  true_mse: 0.0784
#
# level: 24, step_size: 2.2731, prior_norm: 4.2183, likelihood_norm: 0.0532, grad_norm: 4.2185                             image_norm: 133.0887, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0026, grad_mean_norm: 1.2822, train_mse: 0.0002
#  true_mse: 0.0776
#
# level: 25, step_size: 2.1996, prior_norm: 4.2590, likelihood_norm: 0.0535, grad_norm: 4.2612                             image_norm: 133.2025, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0026, grad_mean_norm: 1.3028, train_mse: 0.0002
#  true_mse: 0.0769
#
# level: 26, step_size: 2.1286, prior_norm: 4.2902, likelihood_norm: 0.0527, grad_norm: 4.2906                             image_norm: 133.2824, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0025, grad_mean_norm: 1.3186, train_mse: 0.0002
#  true_mse: 0.0761
#
# level: 27, step_size: 2.0598, prior_norm: 4.3334, likelihood_norm: 0.0530, grad_norm: 4.3353                             image_norm: 133.3877, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0025, grad_mean_norm: 1.3414, train_mse: 0.0002
#  true_mse: 0.0755
#
# level: 28, step_size: 1.9932, prior_norm: 4.3637, likelihood_norm: 0.0523, grad_norm: 4.3642                             image_norm: 133.4610, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0025, grad_mean_norm: 1.3594, train_mse: 0.0002
#  true_mse: 0.0748
#
# level: 29, step_size: 1.9288, prior_norm: 4.4091, likelihood_norm: 0.0525, grad_norm: 4.4108                             image_norm: 133.5587, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0025, grad_mean_norm: 1.3819, train_mse: 0.0002
#  true_mse: 0.0743
#
# level: 30, step_size: 1.8665, prior_norm: 4.4385, likelihood_norm: 0.0520, grad_norm: 4.4392                             image_norm: 133.6252, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0024, grad_mean_norm: 1.3998, train_mse: 0.0002
#  true_mse: 0.0736
# level: 31, step_size: 1.8062, prior_norm: 4.4866, likelihood_norm: 0.0520, grad_norm: 4.4881                             image_norm: 133.7169, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0024, grad_mean_norm: 1.4249, train_mse: 0.0002
#  true_mse: 0.0732
#
# level: 32, step_size: 1.7478, prior_norm: 4.5155, likelihood_norm: 0.0516, grad_norm: 4.5163                             image_norm: 133.7777, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0024, grad_mean_norm: 1.4437, train_mse: 0.0002
#  true_mse: 0.0726
#
# level: 33, step_size: 1.6914, prior_norm: 4.5656, likelihood_norm: 0.0516, grad_norm: 4.5669                             image_norm: 133.8640, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0024, grad_mean_norm: 1.4693, train_mse: 0.0002
#  true_mse: 0.0722
#
# level: 34, step_size: 1.6367, prior_norm: 4.5936, likelihood_norm: 0.0513, grad_norm: 4.5944                             image_norm: 133.9195, snr: inf, prior_mean_norm: 0.0001, likelihood_mean_norm: 0.0024, grad_mean_norm: 1.4888, train_mse: 0.0002
#  true_mse: 0.0716
#
# level: 35, step_size: 1.5838, prior_norm: 4.6469, likelihood_norm: 0.0512, grad_norm: 4.6479                             image_norm: 134.0009, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0024, grad_mean_norm: 1.5169, train_mse: 0.0002
#  true_mse: 0.0712
#
# level: 36, step_size: 1.5326, prior_norm: 4.6731, likelihood_norm: 0.0511, grad_norm: 4.6741                             image_norm: 134.0516, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.5371, train_mse: 0.0002
#  true_mse: 0.0707
#
# level: 37, step_size: 1.4831, prior_norm: 4.7289, likelihood_norm: 0.0509, grad_norm: 4.7296                             image_norm: 134.1289, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.5669, train_mse: 0.0002
#  true_mse: 0.0704
#
# level: 38, step_size: 1.4352, prior_norm: 4.7536, likelihood_norm: 0.0508, grad_norm: 4.7548                             image_norm: 134.1752, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.5875, train_mse: 0.0002
#  true_mse: 0.0699
#
# level: 39, step_size: 1.3888, prior_norm: 4.8113, likelihood_norm: 0.0506, grad_norm: 4.8118                             image_norm: 134.2486, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.6196, train_mse: 0.0002
#  true_mse: 0.0696
#
# level: 40, step_size: 1.3439, prior_norm: 4.8351, likelihood_norm: 0.0506, grad_norm: 4.8365                             image_norm: 134.2908, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.6409, train_mse: 0.0002
#  true_mse: 0.0691
#
# level: 41, step_size: 1.3005, prior_norm: 4.8930, likelihood_norm: 0.0503, grad_norm: 4.8932                             image_norm: 134.3607, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.6740, train_mse: 0.0002
#  true_mse: 0.0689
#
# level: 42, step_size: 1.2585, prior_norm: 4.9175, likelihood_norm: 0.0504, grad_norm: 4.9191                             image_norm: 134.3996, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0023, grad_mean_norm: 1.6974, train_mse: 0.0002
#  true_mse: 0.0684
#
# level: 43, step_size: 1.2178, prior_norm: 4.9736, likelihood_norm: 0.0500, grad_norm: 4.9736                             image_norm: 134.4666, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.7314, train_mse: 0.0002
#  true_mse: 0.0682
#
# level: 44, step_size: 1.1785, prior_norm: 5.0007, likelihood_norm: 0.0502, grad_norm: 5.0025                             image_norm: 134.5030, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.7572, train_mse: 0.0002
#  true_mse: 0.0678
#
# level: 45, step_size: 1.1404, prior_norm: 5.0533, likelihood_norm: 0.0498, grad_norm: 5.0529                             image_norm: 134.5671, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.7897, train_mse: 0.0002
#  true_mse: 0.0676
#
# level: 46, step_size: 1.1036, prior_norm: 5.0841, likelihood_norm: 0.0501, grad_norm: 5.0861                             image_norm: 134.6015, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.8190, train_mse: 0.0002
#  true_mse: 0.0672
#
# level: 47, step_size: 1.0679, prior_norm: 5.1345, likelihood_norm: 0.0495, grad_norm: 5.1340                             image_norm: 134.6627, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.8506, train_mse: 0.0002
#  true_mse: 0.0670
#
# level: 48, step_size: 1.0334, prior_norm: 5.1680, likelihood_norm: 0.0499, grad_norm: 5.1702                             image_norm: 134.6949, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.8832, train_mse: 0.0002
#  true_mse: 0.0666
#
# level: 49, step_size: 1.0000, prior_norm: 5.2155, likelihood_norm: 0.0493, grad_norm: 5.2147                             image_norm: 134.7532, snr: inf, prior_mean_norm: 0.0002, likelihood_mean_norm: 0.0022, grad_mean_norm: 1.9145, train_mse: 0.0002
#  true_mse: 0.0665
#
# TOTAL TIME:  53.86881899833679

# %%
sample = all_samples[-1].view(all_samples[-1].shape[0], new_config.data.channels,
                              new_config.data.image_size,
                              new_config.data.image_size)

sample = torch.clamp(sample, 0.0, 1.0)

# %%
grid_img = torchvision.utils.make_grid(sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()
