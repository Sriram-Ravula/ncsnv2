# %%
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt

import torchvision
from torchvision import transforms

# %% [markdown]
# ## Grab the test data and visualise

# %%
data_path = "/home/sravula/experiments/datasets/8047_vel_imgs.npy"

# %%
from datasets.velocity_fine import Velocity

tran_transform = transforms.Compose([
    transforms.Resize([256, 256])
])

dataset = Velocity(path=data_path, transform=tran_transform)

# %%
N = len(dataset)
indices = list(range(N))
random_state = np.random.get_state()
np.random.seed(2240)
np.random.shuffle(indices)
np.random.set_state(random_state)
train_indices, test_indices = indices[:int(N * 0.9)], indices[int(N * 0.9):]

# %%
test_dataset = torch.utils.data.Subset(dataset, test_indices)

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=15, shuffle=False,
                         num_workers=8, drop_last=True)

test_iter = iter(test_loader)

test_sample = next(test_iter)[0]

# %%
grid_img = torchvision.utils.make_grid(test_sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()

# %% [markdown]
# ## Noise the test data and visualise

# %%
#We want y = Ax where A is a random Gaussian
#y = [N, m, 1], A = [N, m, C x W x H], x = [N, C, H, W]

N, C, H, W = test_sample.shape

m = 1000

# %%
A = (1 / m) * torch.randn(m, C*H*W)
#A = torch.eye(C*H*W)[0:m]
y = torch.matmul(A, test_sample.view(N, -1, 1))

print(A.shape)
print(y.shape)
print(test_sample.shape)
# Out:
# torch.Size([1000, 65536])
# torch.Size([15, 1000, 1])
# torch.Size([15, 1, 256, 256])

# %% [markdown]
# ## Load the network and perform Langevin dynamics on the noisy images

# %%
ckpt_path = "/home/sravula/experiments/logs/run_2/checkpoint.pth"
config_path = "/home/sravula/ncsnv2/configs/velocity.yml"

# %%
import argparse
from main import dict2namespace
import yaml

with open(config_path, 'r') as f:
    config = yaml.load(f)
new_config = dict2namespace(config)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
new_config.device = device

print(device)
# Out:
# cuda
# /home/sravula/venvs/ncsnv2/lib64/python3.6/site-packages/ipykernel_launcher.py:6: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
from models.ncsnv2 import NCSNv2Deepest
from models.ema import EMAHelper
from models import get_sigmas

new_config.input_dim = new_config.data.image_size ** 2 * new_config.data.channels

score = NCSNv2Deepest(new_config).to(new_config.device)
score = torch.nn.DataParallel(score)

#Set up the exponential moving average
if new_config.model.ema:
    ema_helper = EMAHelper(mu=new_config.model.ema_rate)
    ema_helper.register(score)

states = torch.load(ckpt_path)
score.load_state_dict(states[0])
### Make sure we can resume with different eps
states[1]['param_groups'][0]['eps'] = new_config.optim.eps

if new_config.model.ema:
    ema_helper.load_state_dict(states[4])

#grab all L noise levels
sigmas = get_sigmas(new_config)

# %%
test_score = ema_helper.ema_copy(score)

test_score.eval()
# Out:
# DataParallel(
#   (module): NCSNv2Deepest(
#     (act): ELU(alpha=1.0)
#     (begin_conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (normalizer): InstanceNorm2dPlus(
#       (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#     (end_conv): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (res1): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res2): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res3): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res31): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): ConvMeanPool(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res4): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (shortcut): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (res5): ModuleList(
#       (0): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (shortcut): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#       (1): ResidualBlock(
#         (non_linearity): ELU(alpha=1.0)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize2): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#         (normalize1): InstanceNorm2dPlus(
#           (instance_norm): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         )
#       )
#     )
#     (refine1): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine2): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine3): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine31): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine4): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#     (refine5): RefineBlock(
#       (adapt_convs): ModuleList(
#         (0): RCUBlock(
#           (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#         (1): RCUBlock(
#           (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (act): ELU(alpha=1.0)
#         )
#       )
#       (output_convs): RCUBlock(
#         (1_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3_1_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3_2_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (act): ELU(alpha=1.0)
#       )
#       (msf): MSFBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (crp): CRPBlock(
#         (convs): ModuleList(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (maxpool): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (act): ELU(alpha=1.0)
#       )
#     )
#   )
# )

# %%
from models import langevin_Inverse
import time

N, C, H, W = test_sample.shape
print(N, C, H, W)

y = y.to(new_config.device)

A = A.to(new_config.device)

x0 = torch.rand(N, C, H, W, device=new_config.device)

mse = torch.nn.MSELoss()
mse_start = mse(x0, test_sample.to(new_config.device))
print("Start MSE: ", mse_start.item())

start = time.time()

num_iters = 100

all_samples = langevin_Inverse(x_mod = x0, 
                                       y = y, 
                                       A = A, 
                                       scorenet = test_score, 
                                       sigmas = sigmas.cpu().numpy(), 
                                       n_steps_each=1,
                                       step_lr=new_config.sampling.step_lr,
                                       final_only=True, 
                                       verbose=True,
                                       denoise=False,
                                       add_noise=False, 
                                       decimate_sigma=1100//num_iters,
                                       mode=None,
                                       true_x=test_sample.to(new_config.device))

print("\nTOTAL TIME: ", time.time() - start)
# Out:
# 15 1 256 256
# Start MSE:  0.21239666640758514
# /home/sravula/venvs/ncsnv2/lib64/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# level: 0, step_size: 10.0000, prior_norm: 3.4063, likelihood_norm: 0.5422, grad_norm: 3.4863                             image_norm: 134.7289, train_mse: 0.0146
# true_mse: 0.1419
#
# level: 1, step_size: 9.9309, prior_norm: 3.4640, likelihood_norm: 0.5414, grad_norm: 3.4953                             image_norm: 129.7824, train_mse: 0.0051
# true_mse: 0.1089
#
# level: 2, step_size: 9.8623, prior_norm: 3.4563, likelihood_norm: 0.5432, grad_norm: 3.4270                             image_norm: 132.5655, train_mse: 0.0037
# true_mse: 0.1100
#
# level: 3, step_size: 9.7942, prior_norm: 3.4407, likelihood_norm: 0.5415, grad_norm: 3.7898                             image_norm: 131.7973, train_mse: 0.0345
# true_mse: 0.0949
#
# level: 4, step_size: 9.7265, prior_norm: 3.4728, likelihood_norm: 0.5457, grad_norm: 3.6789                             image_norm: 133.9730, train_mse: 0.0054
# true_mse: 0.0949
#
# level: 5, step_size: 9.6594, prior_norm: 3.4919, likelihood_norm: 0.5415, grad_norm: 3.9425                             image_norm: 133.8088, train_mse: 0.0444
# true_mse: 0.0833
#
# level: 6, step_size: 9.5926, prior_norm: 3.5644, likelihood_norm: 0.5477, grad_norm: 3.8795                             image_norm: 135.5919, train_mse: 0.0093
# true_mse: 0.0829
#
# level: 7, step_size: 9.5264, prior_norm: 3.5744, likelihood_norm: 0.5415, grad_norm: 4.0504                             image_norm: 135.7160, train_mse: 0.0452
# true_mse: 0.0737
#
# level: 8, step_size: 9.4606, prior_norm: 3.6268, likelihood_norm: 0.5485, grad_norm: 3.9868                             image_norm: 137.2348, train_mse: 0.0123
# true_mse: 0.0730
#
# level: 9, step_size: 9.3952, prior_norm: 3.6429, likelihood_norm: 0.5415, grad_norm: 4.1199                             image_norm: 137.5921, train_mse: 0.0425
# true_mse: 0.0658
#
# level: 10, step_size: 9.3303, prior_norm: 3.6833, likelihood_norm: 0.5486, grad_norm: 4.0692                             image_norm: 138.9014, train_mse: 0.0147
# true_mse: 0.0648
#
# level: 11, step_size: 9.2659, prior_norm: 3.7046, likelihood_norm: 0.5417, grad_norm: 4.1762                             image_norm: 139.4267, train_mse: 0.0394
# true_mse: 0.0591
#
# level: 12, step_size: 9.2019, prior_norm: 3.7393, likelihood_norm: 0.5487, grad_norm: 4.1427                             image_norm: 140.5570, train_mse: 0.0167
# true_mse: 0.0581
#
# level: 13, step_size: 9.1383, prior_norm: 3.7654, likelihood_norm: 0.5420, grad_norm: 4.2309                             image_norm: 141.1844, train_mse: 0.0368
# true_mse: 0.0537
#
# level: 14, step_size: 9.0752, prior_norm: 3.7978, likelihood_norm: 0.5488, grad_norm: 4.2139                             image_norm: 142.1692, train_mse: 0.0182
# true_mse: 0.0527
#
# level: 15, step_size: 9.0125, prior_norm: 3.8266, likelihood_norm: 0.5423, grad_norm: 4.2869                             image_norm: 142.8497, train_mse: 0.0348
# true_mse: 0.0492
#
# level: 16, step_size: 8.9503, prior_norm: 3.8580, likelihood_norm: 0.5489, grad_norm: 4.2839                             image_norm: 143.7203, train_mse: 0.0194
# true_mse: 0.0482
#
# level: 17, step_size: 8.8884, prior_norm: 3.8886, likelihood_norm: 0.5430, grad_norm: 4.3454                             image_norm: 144.4254, train_mse: 0.0333
# true_mse: 0.0453
#
# level: 18, step_size: 8.8270, prior_norm: 3.9193, likelihood_norm: 0.5490, grad_norm: 4.3530                             image_norm: 145.2016, train_mse: 0.0204
# true_mse: 0.0444
#
# level: 19, step_size: 8.7661, prior_norm: 3.9512, likelihood_norm: 0.5440, grad_norm: 4.4066                             image_norm: 145.9112, train_mse: 0.0321
# true_mse: 0.0421
#
# level: 20, step_size: 8.7055, prior_norm: 3.9828, likelihood_norm: 0.5490, grad_norm: 4.4232                             image_norm: 146.6136, train_mse: 0.0212
# true_mse: 0.0413
#
# level: 21, step_size: 8.6454, prior_norm: 4.0156, likelihood_norm: 0.5450, grad_norm: 4.4710                             image_norm: 147.3124, train_mse: 0.0313
# true_mse: 0.0393
#
# level: 22, step_size: 8.5857, prior_norm: 4.0476, likelihood_norm: 0.5491, grad_norm: 4.4936                             image_norm: 147.9574, train_mse: 0.0218
# true_mse: 0.0385
#
# level: 23, step_size: 8.5263, prior_norm: 4.0814, likelihood_norm: 0.5457, grad_norm: 4.5376                             image_norm: 148.6382, train_mse: 0.0307
# true_mse: 0.0369
#
# level: 24, step_size: 8.4675, prior_norm: 4.1140, likelihood_norm: 0.5494, grad_norm: 4.5649                             image_norm: 149.2361, train_mse: 0.0223
# true_mse: 0.0362
#
# level: 25, step_size: 8.4090, prior_norm: 4.1485, likelihood_norm: 0.5464, grad_norm: 4.6064                             image_norm: 149.8923, train_mse: 0.0303
# true_mse: 0.0347
#
# level: 26, step_size: 8.3509, prior_norm: 4.1818, likelihood_norm: 0.5496, grad_norm: 4.6373                             image_norm: 150.4491, train_mse: 0.0227
# true_mse: 0.0341
#
# level: 27, step_size: 8.2932, prior_norm: 4.2167, likelihood_norm: 0.5472, grad_norm: 4.6771                             image_norm: 151.0775, train_mse: 0.0300
# true_mse: 0.0328
#
# level: 28, step_size: 8.2359, prior_norm: 4.2505, likelihood_norm: 0.5499, grad_norm: 4.7100                             image_norm: 151.5994, train_mse: 0.0230
# true_mse: 0.0323
#
# level: 29, step_size: 8.1790, prior_norm: 4.2860, likelihood_norm: 0.5478, grad_norm: 4.7489                             image_norm: 152.1977, train_mse: 0.0297
# true_mse: 0.0312
#
# level: 30, step_size: 8.1225, prior_norm: 4.3202, likelihood_norm: 0.5501, grad_norm: 4.7831                             image_norm: 152.6881, train_mse: 0.0233
# true_mse: 0.0307
#
# level: 31, step_size: 8.0664, prior_norm: 4.3565, likelihood_norm: 0.5483, grad_norm: 4.8216                             image_norm: 153.2588, train_mse: 0.0295
# true_mse: 0.0297
#
# level: 32, step_size: 8.0107, prior_norm: 4.3912, likelihood_norm: 0.5503, grad_norm: 4.8570                             image_norm: 153.7207, train_mse: 0.0236
# true_mse: 0.0294
#
# level: 33, step_size: 7.9554, prior_norm: 4.4283, likelihood_norm: 0.5488, grad_norm: 4.8959                             image_norm: 154.2641, train_mse: 0.0293
# true_mse: 0.0284
#
# level: 34, step_size: 7.9004, prior_norm: 4.4633, likelihood_norm: 0.5505, grad_norm: 4.9320                             image_norm: 154.6984, train_mse: 0.0238
# true_mse: 0.0281
#
# level: 35, step_size: 7.8458, prior_norm: 4.5009, likelihood_norm: 0.5494, grad_norm: 4.9712                             image_norm: 155.2150, train_mse: 0.0292
# true_mse: 0.0273
#
# level: 36, step_size: 7.7916, prior_norm: 4.5367, likelihood_norm: 0.5509, grad_norm: 5.0086                             image_norm: 155.6227, train_mse: 0.0241
# true_mse: 0.0271
#
# level: 37, step_size: 7.7378, prior_norm: 4.5746, likelihood_norm: 0.5499, grad_norm: 5.0480                             image_norm: 156.1123, train_mse: 0.0291
# true_mse: 0.0263
#
# level: 38, step_size: 7.6844, prior_norm: 4.6111, likelihood_norm: 0.5512, grad_norm: 5.0859                             image_norm: 156.4969, train_mse: 0.0243
# true_mse: 0.0261
#
# level: 39, step_size: 7.6313, prior_norm: 4.6498, likelihood_norm: 0.5502, grad_norm: 5.1257                             image_norm: 156.9623, train_mse: 0.0290
# true_mse: 0.0254
#
# level: 40, step_size: 7.5786, prior_norm: 4.6867, likelihood_norm: 0.5515, grad_norm: 5.1641                             image_norm: 157.3246, train_mse: 0.0245
# true_mse: 0.0252
#
# level: 41, step_size: 7.5262, prior_norm: 4.7262, likelihood_norm: 0.5507, grad_norm: 5.2047                             image_norm: 157.7667, train_mse: 0.0290
# true_mse: 0.0246
#
# level: 42, step_size: 7.4742, prior_norm: 4.7636, likelihood_norm: 0.5518, grad_norm: 5.2436                             image_norm: 158.1066, train_mse: 0.0247
# true_mse: 0.0245
#
# level: 43, step_size: 7.4226, prior_norm: 4.8037, likelihood_norm: 0.5510, grad_norm: 5.2848                             image_norm: 158.5284, train_mse: 0.0289
# true_mse: 0.0239
#
# level: 44, step_size: 7.3713, prior_norm: 4.8417, likelihood_norm: 0.5521, grad_norm: 5.3242                             image_norm: 158.8483, train_mse: 0.0248
# true_mse: 0.0238
#
# level: 45, step_size: 7.3204, prior_norm: 4.8824, likelihood_norm: 0.5513, grad_norm: 5.3659                             image_norm: 159.2517, train_mse: 0.0288
# true_mse: 0.0233
# level: 46, step_size: 7.2699, prior_norm: 4.9210, likelihood_norm: 0.5524, grad_norm: 5.4060                             image_norm: 159.5550, train_mse: 0.0250
# true_mse: 0.0232
#
# level: 47, step_size: 7.2196, prior_norm: 4.9624, likelihood_norm: 0.5516, grad_norm: 5.4481                             image_norm: 159.9438, train_mse: 0.0288
# true_mse: 0.0227
#
# level: 48, step_size: 7.1698, prior_norm: 5.0018, likelihood_norm: 0.5527, grad_norm: 5.4891                             image_norm: 160.2309, train_mse: 0.0252
# true_mse: 0.0227
#
# level: 49, step_size: 7.1203, prior_norm: 5.0439, likelihood_norm: 0.5520, grad_norm: 5.5319                             image_norm: 160.6013, train_mse: 0.0288
# true_mse: 0.0222
#
# level: 50, step_size: 7.0711, prior_norm: 5.0840, likelihood_norm: 0.5530, grad_norm: 5.5735                             image_norm: 160.8713, train_mse: 0.0253
# true_mse: 0.0222
#
# level: 51, step_size: 7.0222, prior_norm: 5.1268, likelihood_norm: 0.5522, grad_norm: 5.6169                             image_norm: 161.2262, train_mse: 0.0287
# true_mse: 0.0218
#
# level: 52, step_size: 6.9737, prior_norm: 5.1674, likelihood_norm: 0.5532, grad_norm: 5.6590                             image_norm: 161.4807, train_mse: 0.0255
# true_mse: 0.0217
#
# level: 53, step_size: 6.9255, prior_norm: 5.2110, likelihood_norm: 0.5525, grad_norm: 5.7031                             image_norm: 161.8203, train_mse: 0.0287
# true_mse: 0.0214
#
# level: 54, step_size: 6.8777, prior_norm: 5.2521, likelihood_norm: 0.5534, grad_norm: 5.7455                             image_norm: 162.0607, train_mse: 0.0256
# true_mse: 0.0213
#
# level: 55, step_size: 6.8302, prior_norm: 5.2967, likelihood_norm: 0.5526, grad_norm: 5.7903                             image_norm: 162.3863, train_mse: 0.0287
# true_mse: 0.0210
#
# level: 56, step_size: 6.7830, prior_norm: 5.3383, likelihood_norm: 0.5536, grad_norm: 5.8333                             image_norm: 162.6103, train_mse: 0.0258
# true_mse: 0.0210
#
# level: 57, step_size: 6.7362, prior_norm: 5.3835, likelihood_norm: 0.5528, grad_norm: 5.8786                             image_norm: 162.9224, train_mse: 0.0287
# true_mse: 0.0207
#
# level: 58, step_size: 6.6896, prior_norm: 5.4259, likelihood_norm: 0.5538, grad_norm: 5.9224                             image_norm: 163.1322, train_mse: 0.0259
# true_mse: 0.0207
#
# level: 59, step_size: 6.6434, prior_norm: 5.4717, likelihood_norm: 0.5531, grad_norm: 5.9682                             image_norm: 163.4294, train_mse: 0.0287
# true_mse: 0.0204
#
# level: 60, step_size: 6.5975, prior_norm: 5.5148, likelihood_norm: 0.5539, grad_norm: 6.0126                             image_norm: 163.6260, train_mse: 0.0260
# true_mse: 0.0204
#
# level: 61, step_size: 6.5520, prior_norm: 5.5613, likelihood_norm: 0.5532, grad_norm: 6.0592                             image_norm: 163.9106, train_mse: 0.0286
# true_mse: 0.0201
#
# level: 62, step_size: 6.5067, prior_norm: 5.6052, likelihood_norm: 0.5541, grad_norm: 6.1043                             image_norm: 164.0944, train_mse: 0.0261
# true_mse: 0.0202
#
# level: 63, step_size: 6.4618, prior_norm: 5.6525, likelihood_norm: 0.5534, grad_norm: 6.1515                             image_norm: 164.3671, train_mse: 0.0286
# true_mse: 0.0199
#
# level: 64, step_size: 6.4171, prior_norm: 5.6971, likelihood_norm: 0.5542, grad_norm: 6.1973                             image_norm: 164.5397, train_mse: 0.0262
# true_mse: 0.0199
#
# level: 65, step_size: 6.3728, prior_norm: 5.7451, likelihood_norm: 0.5536, grad_norm: 6.2453                             image_norm: 164.8006, train_mse: 0.0286
# true_mse: 0.0197
#
# level: 66, step_size: 6.3288, prior_norm: 5.7905, likelihood_norm: 0.5543, grad_norm: 6.2918                             image_norm: 164.9627, train_mse: 0.0263
# true_mse: 0.0198
#
# level: 67, step_size: 6.2851, prior_norm: 5.8391, likelihood_norm: 0.5537, grad_norm: 6.3404                             image_norm: 165.2127, train_mse: 0.0286
# true_mse: 0.0195
#
# level: 68, step_size: 6.2417, prior_norm: 5.8854, likelihood_norm: 0.5544, grad_norm: 6.3878                             image_norm: 165.3636, train_mse: 0.0265
# true_mse: 0.0196
#
# level: 69, step_size: 6.1985, prior_norm: 5.9348, likelihood_norm: 0.5538, grad_norm: 6.4370                             image_norm: 165.6025, train_mse: 0.0286
# true_mse: 0.0194
#
# level: 70, step_size: 6.1557, prior_norm: 5.9818, likelihood_norm: 0.5545, grad_norm: 6.4851                             image_norm: 165.7430, train_mse: 0.0266
# true_mse: 0.0194
#
# level: 71, step_size: 6.1132, prior_norm: 6.0321, likelihood_norm: 0.5539, grad_norm: 6.5351                             image_norm: 165.9718, train_mse: 0.0286
# true_mse: 0.0192
#
# level: 72, step_size: 6.0710, prior_norm: 6.0798, likelihood_norm: 0.5546, grad_norm: 6.5840                             image_norm: 166.1025, train_mse: 0.0267
# true_mse: 0.0193
#
# level: 73, step_size: 6.0290, prior_norm: 6.1308, likelihood_norm: 0.5540, grad_norm: 6.6346                             image_norm: 166.3227, train_mse: 0.0286
# true_mse: 0.0191
#
# level: 74, step_size: 5.9874, prior_norm: 6.1794, likelihood_norm: 0.5547, grad_norm: 6.6842                             image_norm: 166.4447, train_mse: 0.0267
# true_mse: 0.0191
#
# level: 75, step_size: 5.9460, prior_norm: 6.2312, likelihood_norm: 0.5541, grad_norm: 6.7357                             image_norm: 166.6567, train_mse: 0.0286
# true_mse: 0.0190
#
# level: 76, step_size: 5.9050, prior_norm: 6.2806, likelihood_norm: 0.5547, grad_norm: 6.7860                             image_norm: 166.7703, train_mse: 0.0268
# true_mse: 0.0190
#
# level: 77, step_size: 5.8642, prior_norm: 6.3333, likelihood_norm: 0.5542, grad_norm: 6.8382                             image_norm: 166.9737, train_mse: 0.0286
# true_mse: 0.0189
#
# level: 78, step_size: 5.8237, prior_norm: 6.3836, likelihood_norm: 0.5548, grad_norm: 6.8894                             image_norm: 167.0794, train_mse: 0.0269
# true_mse: 0.0189
#
# level: 79, step_size: 5.7834, prior_norm: 6.4369, likelihood_norm: 0.5542, grad_norm: 6.9421                             image_norm: 167.2754, train_mse: 0.0286
# true_mse: 0.0188
#
# level: 80, step_size: 5.7435, prior_norm: 6.4882, likelihood_norm: 0.5549, grad_norm: 6.9945                             image_norm: 167.3737, train_mse: 0.0270
# true_mse: 0.0188
#
# level: 81, step_size: 5.7038, prior_norm: 6.5422, likelihood_norm: 0.5543, grad_norm: 7.0478                             image_norm: 167.5616, train_mse: 0.0286
# true_mse: 0.0187
#
# level: 82, step_size: 5.6644, prior_norm: 6.5944, likelihood_norm: 0.5550, grad_norm: 7.1013                             image_norm: 167.6535, train_mse: 0.0271
# true_mse: 0.0188
#
# level: 83, step_size: 5.6253, prior_norm: 6.6492, likelihood_norm: 0.5543, grad_norm: 7.1553                             image_norm: 167.8340, train_mse: 0.0287
# true_mse: 0.0186
#
# level: 84, step_size: 5.5864, prior_norm: 6.7023, likelihood_norm: 0.5551, grad_norm: 7.2096                             image_norm: 167.9204, train_mse: 0.0271
# true_mse: 0.0187
#
# level: 85, step_size: 5.5478, prior_norm: 6.7578, likelihood_norm: 0.5544, grad_norm: 7.2644                             image_norm: 168.0928, train_mse: 0.0287
# true_mse: 0.0186
#
# level: 86, step_size: 5.5095, prior_norm: 6.8119, likelihood_norm: 0.5552, grad_norm: 7.3196                             image_norm: 168.1736, train_mse: 0.0272
# true_mse: 0.0186
#
# level: 87, step_size: 5.4715, prior_norm: 6.8681, likelihood_norm: 0.5545, grad_norm: 7.3752                             image_norm: 168.3380, train_mse: 0.0287
# true_mse: 0.0185
#
# level: 88, step_size: 5.4337, prior_norm: 6.9232, likelihood_norm: 0.5552, grad_norm: 7.4313                             image_norm: 168.4133, train_mse: 0.0273
# true_mse: 0.0186
#
# level: 89, step_size: 5.3961, prior_norm: 6.9804, likelihood_norm: 0.5546, grad_norm: 7.4878                             image_norm: 168.5707, train_mse: 0.0287
# true_mse: 0.0185
#
# level: 90, step_size: 5.3589, prior_norm: 7.0364, likelihood_norm: 0.5553, grad_norm: 7.5449                             image_norm: 168.6412, train_mse: 0.0273
# true_mse: 0.0185
#
# level: 91, step_size: 5.3219, prior_norm: 7.0946, likelihood_norm: 0.5547, grad_norm: 7.6023                             image_norm: 168.7920, train_mse: 0.0288
# true_mse: 0.0184
# level: 92, step_size: 5.2851, prior_norm: 7.1515, likelihood_norm: 0.5553, grad_norm: 7.6602                             image_norm: 168.8579, train_mse: 0.0274
# true_mse: 0.0185
#
# level: 93, step_size: 5.2486, prior_norm: 7.2106, likelihood_norm: 0.5547, grad_norm: 7.7185                             image_norm: 169.0026, train_mse: 0.0288
# true_mse: 0.0184
#
# level: 94, step_size: 5.2123, prior_norm: 7.2685, likelihood_norm: 0.5554, grad_norm: 7.7774                             image_norm: 169.0642, train_mse: 0.0275
# true_mse: 0.0185
#
# level: 95, step_size: 5.1763, prior_norm: 7.3285, likelihood_norm: 0.5548, grad_norm: 7.8367                             image_norm: 169.2029, train_mse: 0.0288
# true_mse: 0.0184
#
# level: 96, step_size: 5.1406, prior_norm: 7.3875, likelihood_norm: 0.5554, grad_norm: 7.8966                             image_norm: 169.2606, train_mse: 0.0275
# true_mse: 0.0184
#
# level: 97, step_size: 5.1051, prior_norm: 7.4484, likelihood_norm: 0.5548, grad_norm: 7.9566                             image_norm: 169.3939, train_mse: 0.0288
# true_mse: 0.0183
#
# level: 98, step_size: 5.0698, prior_norm: 7.5084, likelihood_norm: 0.5554, grad_norm: 8.0175                             image_norm: 169.4481, train_mse: 0.0276
# true_mse: 0.0184
#
# level: 99, step_size: 5.0348, prior_norm: 7.5702, likelihood_norm: 0.5548, grad_norm: 8.0786                             image_norm: 169.5754, train_mse: 0.0289
# true_mse: 0.0183
#
# level: 100, step_size: 5.0000, prior_norm: 7.6313, likelihood_norm: 0.5554, grad_norm: 8.1405                             image_norm: 169.6260, train_mse: 0.0276
# true_mse: 0.0184
#
# TOTAL TIME:  215.3309977054596

# %%
sample = all_samples[-1].view(all_samples[-1].shape[0], new_config.data.channels,
                              new_config.data.image_size,
                              new_config.data.image_size)

sample = torch.clamp(sample, 0.0, 1.0)

# %%
grid_img = torchvision.utils.make_grid(sample, nrow=5)

dpi = matplotlib.rcParams['figure.dpi']

height = width = 6*256
figsize = width / float(dpi), height / float(dpi)

plt.figure(figsize=figsize)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()
